# %% [markdown]
# ## Data Manipulation With Pandas

# %% [markdown]
# ### Handling Missing Values

# %%
import pandas as pd
import numpy as np

# %%
data1 = {'regiment': ['51st','29th', '2nd', '5th', '45th', '3rd', '20th', '198th', '30th', '1st', '4th', '22nd'],
         'trucks': ['MA7160', np.nan, 'BA3211', 'Tatra10', 'none', 'Tatra10', 'WE2323','Tatra10', 'Tatra10', 'WE2323', 'WE2323', 'Tatra10'],
         'tanks': ['Merkava Mark 4', 'none', 'Merkava Mark 4', 'Leopard 2A6M', 'none', 'Arjun MBT', 'Merkava Mark 4', 'Arjun MBT', 'Leopard 2A6M', 'Arjun MBT', 'Leopard 2A6M', 'Arjun MBT'],
         'aircraft':[ np.nan, 'none', 'none','Harbin Z-9', 'Harbin Z-9', 'Harbin Z-9', 'SH-60B Seahawk', 'SH-60B Seahawk', 'SH-60B Seahawk', 'SH-60B Seahawk','SH-60B Seahawk','SH-60B Seahawk' ]
         }

df = pd.DataFrame(data1)
df
# Out:
#    regiment   trucks           tanks        aircraft
# 0      51st   MA7160  Merkava Mark 4             NaN
# 1      29th      NaN            none            none
# 2       2nd   BA3211  Merkava Mark 4            none
# 3       5th  Tatra10    Leopard 2A6M      Harbin Z-9
# 4      45th     none            none      Harbin Z-9
# 5       3rd  Tatra10       Arjun MBT      Harbin Z-9
# 6      20th   WE2323  Merkava Mark 4  SH-60B Seahawk
# 7     198th  Tatra10       Arjun MBT  SH-60B Seahawk
# 8      30th  Tatra10    Leopard 2A6M  SH-60B Seahawk
# 9       1st   WE2323       Arjun MBT  SH-60B Seahawk
# 10      4th   WE2323    Leopard 2A6M  SH-60B Seahawk
# 11     22nd  Tatra10       Arjun MBT  SH-60B Seahawk

# %%
df['location']=np.nan
df
# Out:
#    regiment   trucks           tanks        aircraft  location
# 0      51st   MA7160  Merkava Mark 4             NaN       NaN
# 1      29th      NaN            none            none       NaN
# 2       2nd   BA3211  Merkava Mark 4            none       NaN
# 3       5th  Tatra10    Leopard 2A6M      Harbin Z-9       NaN
# 4      45th     none            none      Harbin Z-9       NaN
# 5       3rd  Tatra10       Arjun MBT      Harbin Z-9       NaN
# 6      20th   WE2323  Merkava Mark 4  SH-60B Seahawk       NaN
# 7     198th  Tatra10       Arjun MBT  SH-60B Seahawk       NaN
# 8      30th  Tatra10    Leopard 2A6M  SH-60B Seahawk       NaN
# 9       1st   WE2323       Arjun MBT  SH-60B Seahawk       NaN
# 10      4th   WE2323    Leopard 2A6M  SH-60B Seahawk       NaN
# 11     22nd  Tatra10       Arjun MBT  SH-60B Seahawk       NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   regiment  12 non-null     object
#  1   trucks    11 non-null     object
#  2   tanks     12 non-null     object
#  3   aircraft  11 non-null     object
#  4   location  0 non-null      float64
# dtypes: float64(1), object(4)
# memory usage: 608.0+ bytes

# %%
df.isnull().sum()
# Out:
# regiment     0
# trucks       1
# tanks        0
# aircraft     1
# location    12
# dtype: int64

# %%
data_missing={
    'total_missing':df.isnull().sum(),
    'percentage':(df.isnull().sum()/12)*100
}

missing_data=pd.DataFrame(data_missing)
missing_data
# Out:
#           total_missing  percentage
# regiment              0    0.000000
# trucks                1    8.333333
# tanks                 0    0.000000
# aircraft              1    8.333333
# location             12  100.000000

# %%
df.dropna(axis=1,how='all')
# Out:
#    regiment   trucks           tanks        aircraft
# 0      51st   MA7160  Merkava Mark 4             NaN
# 1      29th      NaN            none            none
# 2       2nd   BA3211  Merkava Mark 4            none
# 3       5th  Tatra10    Leopard 2A6M      Harbin Z-9
# 4      45th     none            none      Harbin Z-9
# 5       3rd  Tatra10       Arjun MBT      Harbin Z-9
# 6      20th   WE2323  Merkava Mark 4  SH-60B Seahawk
# 7     198th  Tatra10       Arjun MBT  SH-60B Seahawk
# 8      30th  Tatra10    Leopard 2A6M  SH-60B Seahawk
# 9       1st   WE2323       Arjun MBT  SH-60B Seahawk
# 10      4th   WE2323    Leopard 2A6M  SH-60B Seahawk
# 11     22nd  Tatra10       Arjun MBT  SH-60B Seahawk

# %%
df.dropna(axis=1)
# Out:
#    regiment           tanks
# 0      51st  Merkava Mark 4
# 1      29th            none
# 2       2nd  Merkava Mark 4
# 3       5th    Leopard 2A6M
# 4      45th            none
# 5       3rd       Arjun MBT
# 6      20th  Merkava Mark 4
# 7     198th       Arjun MBT
# 8      30th    Leopard 2A6M
# 9       1st       Arjun MBT
# 10      4th    Leopard 2A6M
# 11     22nd       Arjun MBT

# %%
df=df.drop(['location'],axis=1)
df
# Out:
#    regiment   trucks           tanks        aircraft
# 0      51st   MA7160  Merkava Mark 4             NaN
# 1      29th      NaN            none            none
# 2       2nd   BA3211  Merkava Mark 4            none
# 3       5th  Tatra10    Leopard 2A6M      Harbin Z-9
# 4      45th     none            none      Harbin Z-9
# 5       3rd  Tatra10       Arjun MBT      Harbin Z-9
# 6      20th   WE2323  Merkava Mark 4  SH-60B Seahawk
# 7     198th  Tatra10       Arjun MBT  SH-60B Seahawk
# 8      30th  Tatra10    Leopard 2A6M  SH-60B Seahawk
# 9       1st   WE2323       Arjun MBT  SH-60B Seahawk
# 10      4th   WE2323    Leopard 2A6M  SH-60B Seahawk
# 11     22nd  Tatra10       Arjun MBT  SH-60B Seahawk

# %%
df.dropna()
# Out:
#    regiment   trucks           tanks        aircraft
# 2       2nd   BA3211  Merkava Mark 4            none
# 3       5th  Tatra10    Leopard 2A6M      Harbin Z-9
# 4      45th     none            none      Harbin Z-9
# 5       3rd  Tatra10       Arjun MBT      Harbin Z-9
# 6      20th   WE2323  Merkava Mark 4  SH-60B Seahawk
# 7     198th  Tatra10       Arjun MBT  SH-60B Seahawk
# 8      30th  Tatra10    Leopard 2A6M  SH-60B Seahawk
# 9       1st   WE2323       Arjun MBT  SH-60B Seahawk
# 10      4th   WE2323    Leopard 2A6M  SH-60B Seahawk
# 11     22nd  Tatra10       Arjun MBT  SH-60B Seahawk

# %%
df.dropna(thresh=3)
df
# Out:
#    regiment   trucks           tanks        aircraft
# 0      51st   MA7160  Merkava Mark 4             NaN
# 1      29th      NaN            none            none
# 2       2nd   BA3211  Merkava Mark 4            none
# 3       5th  Tatra10    Leopard 2A6M      Harbin Z-9
# 4      45th     none            none      Harbin Z-9
# 5       3rd  Tatra10       Arjun MBT      Harbin Z-9
# 6      20th   WE2323  Merkava Mark 4  SH-60B Seahawk
# 7     198th  Tatra10       Arjun MBT  SH-60B Seahawk
# 8      30th  Tatra10    Leopard 2A6M  SH-60B Seahawk
# 9       1st   WE2323       Arjun MBT  SH-60B Seahawk
# 10      4th   WE2323    Leopard 2A6M  SH-60B Seahawk
# 11     22nd  Tatra10       Arjun MBT  SH-60B Seahawk

# %%
df.fillna(0)
# Out:
#    regiment   trucks           tanks        aircraft
# 0      51st   MA7160  Merkava Mark 4               0
# 1      29th        0            none            none
# 2       2nd   BA3211  Merkava Mark 4            none
# 3       5th  Tatra10    Leopard 2A6M      Harbin Z-9
# 4      45th     none            none      Harbin Z-9
# 5       3rd  Tatra10       Arjun MBT      Harbin Z-9
# 6      20th   WE2323  Merkava Mark 4  SH-60B Seahawk
# 7     198th  Tatra10       Arjun MBT  SH-60B Seahawk
# 8      30th  Tatra10    Leopard 2A6M  SH-60B Seahawk
# 9       1st   WE2323       Arjun MBT  SH-60B Seahawk
# 10      4th   WE2323    Leopard 2A6M  SH-60B Seahawk
# 11     22nd  Tatra10       Arjun MBT  SH-60B Seahawk

# %%
df.fillna('Unknown')
# Out:
#    regiment   trucks           tanks        aircraft
# 0      51st   MA7160  Merkava Mark 4         Unknown
# 1      29th  Unknown            none            none
# 2       2nd   BA3211  Merkava Mark 4            none
# 3       5th  Tatra10    Leopard 2A6M      Harbin Z-9
# 4      45th     none            none      Harbin Z-9
# 5       3rd  Tatra10       Arjun MBT      Harbin Z-9
# 6      20th   WE2323  Merkava Mark 4  SH-60B Seahawk
# 7     198th  Tatra10       Arjun MBT  SH-60B Seahawk
# 8      30th  Tatra10    Leopard 2A6M  SH-60B Seahawk
# 9       1st   WE2323       Arjun MBT  SH-60B Seahawk
# 10      4th   WE2323    Leopard 2A6M  SH-60B Seahawk
# 11     22nd  Tatra10       Arjun MBT  SH-60B Seahawk

# %%
columns=['trucks','aircraft']
df_2=df.copy()
df_2['trucks']=df_2['trucks'].fillna("unknown-truck")
df_2['aircraft']=df_2['aircraft'].fillna("unknown-aircraft")
df_2
# Out:
#    regiment         trucks           tanks          aircraft
# 0      51st         MA7160  Merkava Mark 4  unknown-aircraft
# 1      29th  unknown-truck            none              none
# 2       2nd         BA3211  Merkava Mark 4              none
# 3       5th        Tatra10    Leopard 2A6M        Harbin Z-9
# 4      45th           none            none        Harbin Z-9
# 5       3rd        Tatra10       Arjun MBT        Harbin Z-9
# 6      20th         WE2323  Merkava Mark 4    SH-60B Seahawk
# 7     198th        Tatra10       Arjun MBT    SH-60B Seahawk
# 8      30th        Tatra10    Leopard 2A6M    SH-60B Seahawk
# 9       1st         WE2323       Arjun MBT    SH-60B Seahawk
# 10      4th         WE2323    Leopard 2A6M    SH-60B Seahawk
# 11     22nd        Tatra10       Arjun MBT    SH-60B Seahawk

# %%
df_2=df.copy()
columns =df_2.columns

for col in columns:
    df_2=df_2.loc[df_2[col]!='none']
    
df_2
# Out:
#    regiment   trucks           tanks        aircraft
# 0      51st   MA7160  Merkava Mark 4             NaN
# 3       5th  Tatra10    Leopard 2A6M      Harbin Z-9
# 5       3rd  Tatra10       Arjun MBT      Harbin Z-9
# 6      20th   WE2323  Merkava Mark 4  SH-60B Seahawk
# 7     198th  Tatra10       Arjun MBT  SH-60B Seahawk
# 8      30th  Tatra10    Leopard 2A6M  SH-60B Seahawk
# 9       1st   WE2323       Arjun MBT  SH-60B Seahawk
# 10      4th   WE2323    Leopard 2A6M  SH-60B Seahawk
# 11     22nd  Tatra10       Arjun MBT  SH-60B Seahawk

# %%
df_2=df.copy()
columns=df_2.columns

for col in columns:
    df_2[df_2[col]=='none']='Unknown'
    
df_2.fillna('Unknown',inplace=True)
df_2
# Out:
#    regiment   trucks           tanks        aircraft
# 0      51st   MA7160  Merkava Mark 4         Unknown
# 1   Unknown  Unknown         Unknown         Unknown
# 2   Unknown  Unknown         Unknown         Unknown
# 3       5th  Tatra10    Leopard 2A6M      Harbin Z-9
# 4   Unknown  Unknown         Unknown         Unknown
# 5       3rd  Tatra10       Arjun MBT      Harbin Z-9
# 6      20th   WE2323  Merkava Mark 4  SH-60B Seahawk
# 7     198th  Tatra10       Arjun MBT  SH-60B Seahawk
# 8      30th  Tatra10    Leopard 2A6M  SH-60B Seahawk
# 9       1st   WE2323       Arjun MBT  SH-60B Seahawk
# 10      4th   WE2323    Leopard 2A6M  SH-60B Seahawk
# 11     22nd  Tatra10       Arjun MBT  SH-60B Seahawk

# %%
df_2=df.copy()
columns=df_2.columns

for col in columns:
    df_2[col] = df_2[col].loc[df_2[col]!='none']

df_2
# Out:
#    regiment   trucks           tanks        aircraft
# 0      51st   MA7160  Merkava Mark 4             NaN
# 1      29th      NaN             NaN             NaN
# 2       2nd   BA3211  Merkava Mark 4             NaN
# 3       5th  Tatra10    Leopard 2A6M      Harbin Z-9
# 4      45th      NaN             NaN      Harbin Z-9
# 5       3rd  Tatra10       Arjun MBT      Harbin Z-9
# 6      20th   WE2323  Merkava Mark 4  SH-60B Seahawk
# 7     198th  Tatra10       Arjun MBT  SH-60B Seahawk
# 8      30th  Tatra10    Leopard 2A6M  SH-60B Seahawk
# 9       1st   WE2323       Arjun MBT  SH-60B Seahawk
# 10      4th   WE2323    Leopard 2A6M  SH-60B Seahawk
# 11     22nd  Tatra10       Arjun MBT  SH-60B Seahawk

# %% [markdown]
# ### Finding Unique Values and Deleting Duplicates

# %%
import pandas as pd
import numpy as np

data1 = {'regiment': ['51st','29th', '2nd', '5th', '45th', '3rd', '20th', '198th', '30th', '1st', '4th', '22nd'],
         'trucks': ['MA7160', np.nan, 'BA3211', 'Tatra10', 'RT3121', 'Tatra10', 'WE2323','Tatra10', 'Tatra10', 'WE2323', 'WE2323', 'Tatra10'],
         'tanks': ['Merkava Mark 4', 'Merkava Mark 4', 'Merkava Mark 4', 'Leopard 2A6M', 'Arjun MBT', 'Arjun MBT', 'Merkava Mark 4', 'Arjun MBT', 'Leopard 2A6M', 'Arjun MBT', 'Leopard 2A6M', 'Arjun MBT'],
         'aircraft':['none', 'none', 'none','Harbin Z-9', 'Harbin Z-9', 'Harbin Z-9', 'SH-60B Seahawk', 'SH-60B Seahawk', 'SH-60B Seahawk', 'SH-60B Seahawk','SH-60B Seahawk','SH-60B Seahawk' ]
         }

df = pd.DataFrame(data1)
df
# Out:
#    regiment   trucks           tanks        aircraft
# 0      51st   MA7160  Merkava Mark 4            none
# 1      29th      NaN  Merkava Mark 4            none
# 2       2nd   BA3211  Merkava Mark 4            none
# 3       5th  Tatra10    Leopard 2A6M      Harbin Z-9
# 4      45th   RT3121       Arjun MBT      Harbin Z-9
# 5       3rd  Tatra10       Arjun MBT      Harbin Z-9
# 6      20th   WE2323  Merkava Mark 4  SH-60B Seahawk
# 7     198th  Tatra10       Arjun MBT  SH-60B Seahawk
# 8      30th  Tatra10    Leopard 2A6M  SH-60B Seahawk
# 9       1st   WE2323       Arjun MBT  SH-60B Seahawk
# 10      4th   WE2323    Leopard 2A6M  SH-60B Seahawk
# 11     22nd  Tatra10       Arjun MBT  SH-60B Seahawk

# %%
set(df_2['trucks'])
# Out:
# {'BA3211', 'MA7160', 'Tatra10', 'WE2323', nan}

# %%
df_2['trucks'].unique()
# Out:
# array(['MA7160', nan, 'BA3211', 'Tatra10', 'WE2323'], dtype=object)

# %%
df_2['trucks'].value_counts()
# Out:
# Tatra10    5
# WE2323     3
# MA7160     1
# BA3211     1
# Name: trucks, dtype: int64

# %% [markdown]
# To find obsevation containing duplicated data, follow :

# %%
import pandas as pd

data1 = {'regiment': ['51st','51st', '51st','51st','29th', '2nd', '5th', '45th', '3rd', '20th', '198th', '30th'],
         'trucks': ['MA7160', 'MA7160', 'MA7160', 'MA7160','MA7160', 'BA3211', 'Tatra10', 'RT3121', 'Tatra10', 'WE2323','Tatra10', 'Tatra10'],
         'tanks': ['Merkava Mark 4', 'Merkava Mark 4', 'Merkava Mark 4', 'Merkava Mark 4', 'Merkava Mark 4', 'Merkava Mark 4', 'Leopard 2A6M', 'Arjun MBT', 'Arjun MBT', 'Merkava Mark 4', 'Arjun MBT', 'Leopard 2A6M'],
         'aircraft':['none', 'none', 'none', 'none', 'Harbin Z-9', 'none','Harbin Z-9', 'Harbin Z-9', 'Harbin Z-9', 'SH-60B Seahawk', 'SH-60B Seahawk', 'SH-60B Seahawk']
         }

df = pd.DataFrame(data1)
df
# Out:
#    regiment   trucks           tanks        aircraft
# 0      51st   MA7160  Merkava Mark 4            none
# 1      51st   MA7160  Merkava Mark 4            none
# 2      51st   MA7160  Merkava Mark 4            none
# 3      51st   MA7160  Merkava Mark 4            none
# 4      29th   MA7160  Merkava Mark 4      Harbin Z-9
# 5       2nd   BA3211  Merkava Mark 4            none
# 6       5th  Tatra10    Leopard 2A6M      Harbin Z-9
# 7      45th   RT3121       Arjun MBT      Harbin Z-9
# 8       3rd  Tatra10       Arjun MBT      Harbin Z-9
# 9      20th   WE2323  Merkava Mark 4  SH-60B Seahawk
# 10    198th  Tatra10       Arjun MBT  SH-60B Seahawk
# 11     30th  Tatra10    Leopard 2A6M  SH-60B Seahawk

# %%
df.duplicated().sum()
# Out:
# 3

# %% [markdown]
# To remove duplicates, we use drop_duplicates()

# %%
df.drop_duplicates()
# Out:
#    regiment   trucks           tanks        aircraft
# 0      51st   MA7160  Merkava Mark 4            none
# 4      29th   MA7160  Merkava Mark 4      Harbin Z-9
# 5       2nd   BA3211  Merkava Mark 4            none
# 6       5th  Tatra10    Leopard 2A6M      Harbin Z-9
# 7      45th   RT3121       Arjun MBT      Harbin Z-9
# 8       3rd  Tatra10       Arjun MBT      Harbin Z-9
# 9      20th   WE2323  Merkava Mark 4  SH-60B Seahawk
# 10    198th  Tatra10       Arjun MBT  SH-60B Seahawk
# 11     30th  Tatra10    Leopard 2A6M  SH-60B Seahawk

# %% [markdown]
# ### Analysing Outliers

# %%
height_data = {'name':['Adit', 'Gia', 'Tim', 'Mark', 'Nur', 'Adil', 'Kia', 'Indar', 'Tia', 'Jack', 'Adele', 'Niall', 'Harry', 'Tom'],
               'height': [5.9, 5.2, 5.1, 5.5, 4.9, 5.4, 6.2, 6.5, 7.1, 14.5, 6.1, 5.6, 1.2, 5.5]}
df = pd.DataFrame(height_data)
df
# Out:
#      name  height
# 0    Adit     5.9
# 1     Gia     5.2
# 2     Tim     5.1
# 3    Mark     5.5
# 4     Nur     4.9
# 5    Adil     5.4
# 6     Kia     6.2
# 7   Indar     6.5
# 8     Tia     7.1
# 9    Jack    14.5
# 10  Adele     6.1
# 11  Niall     5.6
# 12  Harry     1.2
# 13    Tom     5.5

# %% [markdown]
# #### Boxplot

# %%
height_data = {'name':['Adit', 'Gia', 'Tim', 'Mark', 'Nur', 'Adil', 'Kia', 'Indar', 'Tia', 'Jack', 'Adele', 'Niall', 'Harry', 'Tom'],
               'height': [5.9, 5.2, 5.1, 5.5, 4.9, 5.4, 6.2, 6.5, 7.1, 14.5, 6.1, 5.6, 1.2, 5.5]}
df = pd.DataFrame(height_data)

df_copy=df.copy()
df_copy=df_copy['height'].astype(int)

import matplotlib.pyplot as plt
# %matplotlib inline
plt.boxplot(df_copy)
plt.show()

# %%
Q3=df['height'].quantile(0.75)
Q1=df['height'].quantile(0.25)
IQR=Q3-Q1

max_threshold=Q3+(1.5*IQR)
max_threshold
# Out:
# 7.5625

# %%
min_threshold=Q1-(1.5*IQR)
min_threshold
# Out:
# 3.8625000000000003

# %%
df[df['height']>max_threshold]
# Out:
#    name  height
# 9  Jack    14.5

# %%
df[df['height']<min_threshold]
# Out:
#      name  height
# 12  Harry     1.2

# %%
new_df=df[(df['height']<max_threshold)&(df['height']>min_threshold)]
new_df
# Out:
#      name  height
# 0    Adit     5.9
# 1     Gia     5.2
# 2     Tim     5.1
# 3    Mark     5.5
# 4     Nur     4.9
# 5    Adil     5.4
# 6     Kia     6.2
# 7   Indar     6.5
# 8     Tia     7.1
# 10  Adele     6.1
# 11  Niall     5.6
# 13    Tom     5.5

# %%
new_df=new_df['height'].astype(int)

plt.boxplot(new_df)
plt.show()
